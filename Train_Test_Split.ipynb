# %% [markdown]
# <a href="https://colab.research.google.com/github/erdalbucan/Colab/blob/main/Train_Test_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# makine ogrenmesi FORMUL  y = m1x1 + m2x2 + mnxn + b

# %%
# https://www.kaggle.com/datasets/jacklacey/audi-a1-listings/data adresinden Audi_A1_listings.csv datadini indirdik
#pd.read_cvs ile dizindeki audi.csv dosyamizi okuyup df degiskenine taniimliyoruz
df = pd.read_csv('audi.csv')
df.head(3)
# Out:
#    index    Year       Type  Mileage(miles) Engine          PS Transmission  \
# 0      0  2018.0  Hatchback         44000.0   1.6L  114.398422       Manual
# 1      4  2016.0  Hatchback         42596.0   1.0L   93.688363       Manual
# 2      7  2015.0  Hatchback         42700.0   1.4L  123.274162       Manual
#
#      Fuel  Number_of_Owners  Price(£)  \
# 0  Diesel                 1   14995.0
# 1  Petrol                 3   10755.0
# 2  Petrol                 2   10799.0
#
#                                                 href          PPY  \
# 0  https://www.autotrader.co.uk/car-details/20221...  2499.166667
# 1  https://www.autotrader.co.uk/car-details/20221...  2688.750000
# 2  https://www.autotrader.co.uk/car-details/20221...  3599.666667
#
#    MileageRank  PriceRank  PPYRank  Score
# 0          215        163      340    718
# 1          222        330      276    828
# 2          221        327       94    642

# %%
# makine ogrenmesi icin ihtiyacimiz olmayan sutunlari temizleyelim
#bu datada fiyat tahmini icin araba linklerine ranklara ihtiyacim yok
df = df.drop(columns= ['index','href','MileageRank','PriceRank','PPY','PPYRank','Score'])
df.head(3)
# Out:
#      Year       Type  Mileage(miles) Engine          PS Transmission    Fuel  \
# 0  2018.0  Hatchback         44000.0   1.6L  114.398422       Manual  Diesel
# 1  2016.0  Hatchback         42596.0   1.0L   93.688363       Manual  Petrol
# 2  2015.0  Hatchback         42700.0   1.4L  123.274162       Manual  Petrol
#
#    Number_of_Owners  Price(£)
# 0                 1   14995.0
# 1                 3   10755.0
# 2                 2   10799.0

# %%
# Type , Transmission, Fuel gibi veriler KATEGORISEL rakamsal veriler ise NUMERIK verilerdir.

# y = mx + b  Y =tahmin edilecek veri x = etki katsayisi m = etki eden faktor (dizel, motor, yil vb. her biri ayri m1x1 m2x2 mnxn) b = sabit
# Data mizi Numerik veriye donusturmemiz gerekiyor.

# Datamizin neleri numerige cevirmemiz gerektigini ogrenmek icin pd.info()
df.info()
#Fload ve int harici butun verilerimiz Kategorisel veri imis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              471 non-null    float64
#  1   Type              471 non-null    object
#  2   Mileage(miles)    471 non-null    float64
#  3   Engine            471 non-null    object
#  4   PS                471 non-null    float64
#  5   Transmission      471 non-null    object
#  6   Fuel              471 non-null    object
#  7   Number_of_Owners  471 non-null    int64
#  8   Price(£)          471 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 33.2+ KB

# %%
# oncelikle sutun adlarini degistirmekle baslayalim
# oncelikle Engin sutununu NUmerik veriye donustirmekle baslayalim
df.columns=['yil','kasa','mil','motor','ps','vites','yakit','sahip','fiyat']
df.head(3)
# Out:
#       yil       kasa      mil motor          ps   vites   yakit  sahip  \
# 0  2018.0  Hatchback  44000.0  1.6L  114.398422  Manual  Diesel      1
# 1  2016.0  Hatchback  42596.0  1.0L   93.688363  Manual  Petrol      3
# 2  2015.0  Hatchback  42700.0  1.4L  123.274162  Manual  Petrol      2
#
#      fiyat
# 0  14995.0
# 1  10755.0
# 2  10799.0

# %%
# motor sutundaki L ibarelerini str.replace komutuyla degistiriyorum
df['motor'] = df['motor'].str.replace('L','')
df.head(3)
#numerige benzedi fakat sutun henuz object olarak tanimli. int yada fload a cevirmek gerekiyor
# Out:
#       yil       kasa      mil motor          ps   vites   yakit  sahip  \
# 0  2018.0  Hatchback  44000.0   1.6  114.398422  Manual  Diesel      1
# 1  2016.0  Hatchback  42596.0   1.0   93.688363  Manual  Petrol      3
# 2  2015.0  Hatchback  42700.0   1.4  123.274162  Manual  Petrol      2
#
#      fiyat
# 0  14995.0
# 1  10755.0
# 2  10799.0

# %%
#numerige donuzmeye uygunlastirdigimiz motor sutunumuzu  to_numeric comutuyla numerige donusturuyoruz
df['motor'] = pd.to_numeric( df ['motor'] )
df['motor'].head(3)
# object olan motor sutunumuz artik fload
# Out:
# 0    1.6
# 1    1.0
# 2    1.4
# Name: motor, dtype: float64

# %%
# simdi direk kategorisel verileri numerige cevirecegiz get_dummies comutuyla
df= pd.get_dummies(df,columns=['kasa','vites','yakit'],drop_first=True) # drop_first=True iki veri yi teke cevir- yani oto vites ile man vites ayri olmaasin. oto vites 0 ise man vites demektir
df.head(5)
# Artik verimiz model olusturmak icin hazir. butun sutunlari NUMERIC
# Out:
#       yil       mil  motor          ps  sahip    fiyat  vites_Manual  \
# 0  2018.0   44000.0    1.6  114.398422      1  14995.0          True
# 1  2016.0   42596.0    1.0   93.688363      3  10755.0          True
# 2  2015.0   42700.0    1.4  123.274162      2  10799.0          True
# 3  2014.0   86000.0    1.6  103.550296      3   7490.0          True
# 4  2014.0  104310.0    1.6  103.550296      3   7400.0          True
#
#    yakit_Petrol
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False

# %%
# datamiz hazir. makine ogrenmesine gecebiliriz
# oncelikle x ve y mizi tanimliyoruz
# y = mx+b y= tahmin etmek istedigimiz veri = fiyat
y = df[['fiyat']]
# x diger butun etkenler x
x = df.drop('fiyat', axis = 1 ) # fiyat haricinde hepsi x olsun anlamina gelir yada x = df[['yil','motor',vs, vs]] yazabilir
df.head()
# Out:
#       yil       mil  motor          ps  sahip    fiyat  vites_Manual  \
# 0  2018.0   44000.0    1.6  114.398422      1  14995.0          True
# 1  2016.0   42596.0    1.0   93.688363      3  10755.0          True
# 2  2015.0   42700.0    1.4  123.274162      2  10799.0          True
# 3  2014.0   86000.0    1.6  103.550296      3   7490.0          True
# 4  2014.0  104310.0    1.6  103.550296      3   7400.0          True
#
#    yakit_Petrol
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False

# %%
# # modelimizi olusturuyoruz
# lm = LinearRegression()
# model = lm.fit(x,y) #modeli fit ediyoruz ogretiyoruz
# model.score(x,y) # tahmin dogruluk derecesi %91 cikti
# FIT ogretiyoruz / SCORE test ediyoruz
# DAHA DERIN SCORE YAPMAK ICIN BU YONTEMI SIMDILIK YORUMA CEVIRIP ATLIYORUZ

# %%
#yukardaki kodu yazmadan once veriyi bolecegiz
# size 100 soru veriyorum, ve sinaavda 100 sorudan bikacini soruyorum daan
# size 100 sorunun 70 sini veriyorum, sinaavda size vermemis oldugun 30 sorudan sinav yapiyorum
# score dusuyor aama daha aguvenilir.
# train_test_split kutuphaanesi ile yapiyoruz
# FIT ogretiyoruz / SCORE test ediyoruz
# train_test_split
x_train, x_test, y_train, y_test = train_test_split (x , y , train_size = .7, random_state = 571 )
#x,y dayasini TRAIN ve TEST olarak ikiye bolduk. ve TRAIN_SIZE=0.70 belirledik yada TEST_SIZE=0.30 yada baskabir yuzde
# random_state ekliyoruz ve herhangibir deger atiyoruz ben rizenin plakasini atadim

# %%
#simdi modelimize maslayabiliriz
# FIT ogrenmeti trane datasiyla yapacagiz ve SCORE ti test datasiyla yaapacagiz
lm = LinearRegression()
model = lm.fit(x_train, y_train) # datanin %70 ile ogrettik
model.score(x_test, y_test) # sakladigimiz % 30 dataada sorular sorduk TEST ETTIK
# SCORE %90 civarina geriledi ama dahaa guvenilir score
# Out:
# 0.9093573890252779

# %%
# bir deneme yapalim
df.head(3)
# Out:
#       yil      mil  motor          ps  sahip    fiyat  vites_Manual  \
# 0  2018.0  44000.0    1.6  114.398422      1  14995.0          True
# 1  2016.0  42596.0    1.0   93.688363      3  10755.0          True
# 2  2015.0  42700.0    1.4  123.274162      2  10799.0          True
#
#    yakit_Petrol
# 0         False
# 1          True
# 2          True

# %%
# verdigimiz verilere gore fiyat tahmini istiyorus
model.predict([[2016, 40000, 1.0, 95, 3, 0, 0]])
#boyle bir aracin fiyatinin 14942 paund oldugunu tahmin ettik ve bu taahmin %90 dogru bir tahmin cunki scoremiz %90
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[14942.19590537]])
